# %% [markdown]
# # *Merged Jupyter Notebook*

# %% [markdown]
# <hr><font color="green"><h1>from file: 01_</h1></font>

# %%
print("first")

# %% [markdown]
# <hr><font color="green"><h1>from file: 02_</h1></font>

# %%
print("third")

# %% [markdown]
# <hr><font color="green"><h1>from file: 03_ </h1></font>

# %%
print("first")
